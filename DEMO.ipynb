# %% [markdown]
# ## OCR PINELINE DEMO
# ### this is the demo for RnD pineline with data from DAICHI_LIFE POC

# %% [markdown]
# import necessary for the notebok

# %%
from IPython.display import Image
import os

# %%
demo_dir = './result'

# %% [markdown]
# #### original image for OCR

# %%
Image(os.path.join(demo_dir,'origin','SG1-1-1.jpg'),width=500,height=1000)

# %% [markdown]
# #### Line Cut Result

# %%
Image(os.path.join(demo_dir,'line_cut','image.png'),width=500,height=1000)

# %% [markdown]
# #### OCR Result
